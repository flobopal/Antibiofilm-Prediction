# %% [markdown]
# # Data Loading

# %%
import pandas as pd

data = pd.read_csv("predictions.csv", index_col = 0)
data.rename(columns={"pIC50": "real pIC50", "y_pred": "predicted pIC50"}, inplace=True)
data = data[["target_organism", "real pIC50", "predicted pIC50"]]
data.head()
# Out:
#                                         target_organism  real pIC50  \
# 3218  Salmonella enterica subsp. enterica serovar Ty...    1.501689
# 9448                              Staphylococcus aureus    1.966172
# 2491                              Raoultella planticola    2.958607
# 319   Salmonella enterica subsp. enterica serovar Ty...    1.478862
# 508                               Staphylococcus aureus    1.271646
#
#       predicted pIC50
# 3218         1.861674
# 9448         2.710427
# 2491         3.128974
# 319          1.491442
# 508          1.538545

# %% [markdown]
# # Prediction Analysis

# %% [markdown]
# ## Metrics

# %%
y_real = data["real pIC50"]
y_pred = data["predicted pIC50"]

from sklearn.metrics import r2_score, mean_squared_error
print("R² score: ", r2_score(y_real, y_pred))
print("MSE: ", mean_squared_error(y_real, y_pred))
print("RMSE:", mean_squared_error(y_real, y_pred)**0.5)
# Out:
# R² score:  0.4909347144031698
# MSE:  0.25094578499839265
# RMSE: 0.5009448921771662

# %% [markdown]
# # Graph

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.scatterplot(x = y_real, y= y_pred)
sns.lineplot(x = [0,4], y=[0,4])
sns.lineplot(x = [0,4], y=[0.5, 4.5])
sns.lineplot(x = [0,4], y=[-0.5, 3.5])
plt.xlabel('real pIC50')
plt.ylabel('predicted pIC50')
# Out:
# Text(0, 0.5, 'predicted pIC50')

# %%
sns.histplot((y_real-y_pred), bins=16, binrange=(-2, 2))
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# ## RESULTS BY SPECIES

# %%
fig, axes = plt.subplots(2, 4, sharex="all", sharey="all", figsize = (20, 8))
for i, specie in enumerate(data.target_organism.unique()):
    ax = axes[i//4][i%4]
    sns.scatterplot(data[data.target_organism.eq(specie)], x="real pIC50", y="predicted pIC50", ax=ax)
    sns.lineplot(x = [0,4], y=[0,4], ax=ax)
    sns.lineplot(x = [0,4], y=[0.5, 4.5], ax=ax)
    sns.lineplot(x = [0,4], y=[-0.5, 3.5], ax=ax)
    ax.set_title(specie)

# %%
from collections import defaultdict

metrics = defaultdict(dict)

for specie in data.target_organism.unique():
    subdata = data[data.target_organism.eq(specie)]
    y = subdata["real pIC50"]
    y_pred = subdata["predicted pIC50"]
    metrics["R2"][specie] = r2_score(y, y_pred)
    metrics["MSE"][specie] =  mean_squared_error(y, y_pred)
    metrics["RMSE"][specie] =  mean_squared_error(y, y_pred)**0.5

metrics = pd.DataFrame(metrics)

metrics
# Out:
#                                                           R2       MSE  \
# Salmonella enterica subsp. enterica serovar Typ...  0.414972  0.271771
# Staphylococcus aureus                               0.483865  0.277019
# Raoultella planticola                               0.420586  0.180715
# Escherichia coli                                    0.620907  0.229399
# Mycolicibacterium smegmatis                         0.188423  0.054875
# Streptococcus mutans                                0.315719  0.346613
# Bacillus subtilis                                  -0.508809  0.185350
# Pseudoalteromonas ulvae                             0.597499  0.113019
#
#                                                         RMSE
# Salmonella enterica subsp. enterica serovar Typ...  0.521316
# Staphylococcus aureus                               0.526326
# Raoultella planticola                               0.425106
# Escherichia coli                                    0.478956
# Mycolicibacterium smegmatis                         0.234254
# Streptococcus mutans                                0.588739
# Bacillus subtilis                                   0.430523
# Pseudoalteromonas ulvae                             0.336183
